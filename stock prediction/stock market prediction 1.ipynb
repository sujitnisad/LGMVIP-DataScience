# %%
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
import io
import requests 
import datetime

# %%
url="https://raw.githubusercontent.com/mwitiderrick/stockprice/master/NSE-TATAGLOBAL.csv"
df=pd.read_csv(url)

# %%
df.head()
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  2018-09-28  234.05  235.95  230.20  233.50  233.75               3069914
# 1  2018-09-27  234.55  236.80  231.10  233.80  233.25               5082859
# 2  2018-09-26  240.00  240.00  232.50  235.00  234.25               2240909
# 3  2018-09-25  233.30  236.75  232.00  236.25  236.10               2349368
# 4  2018-09-24  233.55  239.20  230.75  234.00  233.30               3423509
#
#    Turnover (Lacs)
# 0          7162.35
# 1         11859.95
# 2          5248.60
# 3          5503.90
# 4          7999.55

# %%
df
# Out:
#             Date    Open    High     Low    Last   Close  \
# 0     2018-09-28  234.05  235.95  230.20  233.50  233.75
# 1     2018-09-27  234.55  236.80  231.10  233.80  233.25
# 2     2018-09-26  240.00  240.00  232.50  235.00  234.25
# 3     2018-09-25  233.30  236.75  232.00  236.25  236.10
# 4     2018-09-24  233.55  239.20  230.75  234.00  233.30
# ...          ...     ...     ...     ...     ...     ...
# 2030  2010-07-27  117.60  119.50  112.00  118.80  118.65
# 2031  2010-07-26  120.10  121.00  117.10  117.10  117.60
# 2032  2010-07-23  121.80  121.95  120.25  120.35  120.65
# 2033  2010-07-22  120.30  122.00  120.25  120.75  120.90
# 2034  2010-07-21  122.10  123.00  121.05  121.10  121.55
#
#       Total Trade Quantity  Turnover (Lacs)
# 0                  3069914          7162.35
# 1                  5082859         11859.95
# 2                  2240909          5248.60
# 3                  2349368          5503.90
# 4                  3423509          7999.55
# ...                    ...              ...
# 2030                586100           694.98
# 2031                658440           780.01
# 2032                281312           340.31
# 2033                293312           355.17
# 2034                658666           803.56
#
# [2035 rows x 8 columns]

# %%
df.shape
# Out:
# (2035, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2035 entries, 0 to 2034
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  2035 non-null   object
#  1   Open                  2035 non-null   float64
#  2   High                  2035 non-null   float64
#  3   Low                   2035 non-null   float64
#  4   Last                  2035 non-null   float64
#  5   Close                 2035 non-null   float64
#  6   Total Trade Quantity  2035 non-null   int64
#  7   Turnover (Lacs)       2035 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 127.3+ KB

# %%
df.describe()
# Out:
#               Open         High          Low         Last       Close  \
# count  2035.000000  2035.000000  2035.000000  2035.000000  2035.00000
# mean    149.713735   151.992826   147.293931   149.474251   149.45027
# std      48.664509    49.413109    47.931958    48.732570    48.71204
# min      81.100000    82.800000    80.000000    81.000000    80.95000
# 25%     120.025000   122.100000   118.300000   120.075000   120.05000
# 50%     141.500000   143.400000   139.600000   141.100000   141.25000
# 75%     157.175000   159.400000   155.150000   156.925000   156.90000
# max     327.700000   328.750000   321.650000   325.950000   325.75000
#
#        Total Trade Quantity  Turnover (Lacs)
# count          2.035000e+03      2035.000000
# mean           2.335681e+06      3899.980565
# std            2.091778e+06      4570.767877
# min            3.961000e+04        37.040000
# 25%            1.146444e+06      1427.460000
# 50%            1.783456e+06      2512.030000
# 75%            2.813594e+06      4539.015000
# max            2.919102e+07     55755.080000

# %%
df.dtypes
# Out:
# Date                     object
# Open                    float64
# High                    float64
# Low                     float64
# Last                    float64
# Close                   float64
# Total Trade Quantity      int64
# Turnover (Lacs)         float64
# dtype: object

# %%
missing_values_count = df.isnull().sum()

total_cells = np.product(df.shape)

total_missing = missing_values_count.sum()

percentage_missing = (total_missing/total_cells)*100
print(percentage_missing)
# Out:
# 0.0

# %%
NAN = [(c, df[c].isnull().mean()*100) for c in df]
NAN = pd.DataFrame(NAN, columns=['column_name', 'percentage'])
NAN
# Out:
#             column_name  percentage
# 0                  Date         0.0
# 1                  Open         0.0
# 2                  High         0.0
# 3                   Low         0.0
# 4                  Last         0.0
# 5                 Close         0.0
# 6  Total Trade Quantity         0.0
# 7       Turnover (Lacs)         0.0

# %%
sns.set(rc = {'figure.figsize': (20, 5)})
df['Open'].plot(linewidth = 1,color='blue')
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Last', 'Close', 'Total Trade Quantity',
#        'Turnover (Lacs)'],
#       dtype='object')

# %%
cols_plot = ['Open','High','Low','Last','Close']
axes = df[cols_plot].plot(alpha = 1, figsize=(20, 30), subplots = True)

for ax in axes:
    ax.set_ylabel('Variation')

# %%
df["Date"]=pd.to_datetime(df.Date,format="%Y-%m-%d")
df.index=df['Date']

# %%
df
# Out:
#                  Date    Open    High     Low    Last   Close  \
# Date
# 2018-09-28 2018-09-28  234.05  235.95  230.20  233.50  233.75
# 2018-09-27 2018-09-27  234.55  236.80  231.10  233.80  233.25
# 2018-09-26 2018-09-26  240.00  240.00  232.50  235.00  234.25
# 2018-09-25 2018-09-25  233.30  236.75  232.00  236.25  236.10
# 2018-09-24 2018-09-24  233.55  239.20  230.75  234.00  233.30
# ...               ...     ...     ...     ...     ...     ...
# 2010-07-27 2010-07-27  117.60  119.50  112.00  118.80  118.65
# 2010-07-26 2010-07-26  120.10  121.00  117.10  117.10  117.60
# 2010-07-23 2010-07-23  121.80  121.95  120.25  120.35  120.65
# 2010-07-22 2010-07-22  120.30  122.00  120.25  120.75  120.90
# 2010-07-21 2010-07-21  122.10  123.00  121.05  121.10  121.55
#
#             Total Trade Quantity  Turnover (Lacs)
# Date
# 2018-09-28               3069914          7162.35
# 2018-09-27               5082859         11859.95
# 2018-09-26               2240909          5248.60
# 2018-09-25               2349368          5503.90
# 2018-09-24               3423509          7999.55
# ...                          ...              ...
# 2010-07-27                586100           694.98
# 2010-07-26                658440           780.01
# 2010-07-23                281312           340.31
# 2010-07-22                293312           355.17
# 2010-07-21                658666           803.56
#
# [2035 rows x 8 columns]

# %%
del df["Date"]

# %%
df
# Out:
#               Open    High     Low    Last   Close  Total Trade Quantity  \
# Date
# 2018-09-28  234.05  235.95  230.20  233.50  233.75               3069914
# 2018-09-27  234.55  236.80  231.10  233.80  233.25               5082859
# 2018-09-26  240.00  240.00  232.50  235.00  234.25               2240909
# 2018-09-25  233.30  236.75  232.00  236.25  236.10               2349368
# 2018-09-24  233.55  239.20  230.75  234.00  233.30               3423509
# ...            ...     ...     ...     ...     ...                   ...
# 2010-07-27  117.60  119.50  112.00  118.80  118.65                586100
# 2010-07-26  120.10  121.00  117.10  117.10  117.60                658440
# 2010-07-23  121.80  121.95  120.25  120.35  120.65                281312
# 2010-07-22  120.30  122.00  120.25  120.75  120.90                293312
# 2010-07-21  122.10  123.00  121.05  121.10  121.55                658666
#
#             Turnover (Lacs)
# Date
# 2018-09-28          7162.35
# 2018-09-27         11859.95
# 2018-09-26          5248.60
# 2018-09-25          5503.90
# 2018-09-24          7999.55
# ...                     ...
# 2010-07-27           694.98
# 2010-07-26           780.01
# 2010-07-23           340.31
# 2010-07-22           355.17
# 2010-07-21           803.56
#
# [2035 rows x 7 columns]

# %%
df.dtypes
# Out:
# Open                    float64
# High                    float64
# Low                     float64
# Last                    float64
# Close                   float64
# Total Trade Quantity      int64
# Turnover (Lacs)         float64
# dtype: object

# %%
df.rolling(7).mean().head(10)
# Out:
#                   Open        High         Low        Last       Close  \
# Date
# 2018-09-28         NaN         NaN         NaN         NaN         NaN
# 2018-09-27         NaN         NaN         NaN         NaN         NaN
# 2018-09-26         NaN         NaN         NaN         NaN         NaN
# 2018-09-25         NaN         NaN         NaN         NaN         NaN
# 2018-09-24         NaN         NaN         NaN         NaN         NaN
# 2018-09-21         NaN         NaN         NaN         NaN         NaN
# 2018-09-19  235.200000  237.557143  231.135714  234.414286  234.307143
# 2018-09-18  235.750000  238.028571  231.607143  234.700000  234.492857
# 2018-09-17  235.550000  238.200000  231.485714  235.071429  234.971429
# 2018-09-14  233.185714  237.728571  230.171429  234.928571  234.928571
#
#             Total Trade Quantity  Turnover (Lacs)
# Date
# 2018-09-28                   NaN              NaN
# 2018-09-27                   NaN              NaN
# 2018-09-26                   NaN              NaN
# 2018-09-25                   NaN              NaN
# 2018-09-24                   NaN              NaN
# 2018-09-21                   NaN              NaN
# 2018-09-19          3.274848e+06      7652.388571
# 2018-09-18          3.209831e+06      7509.724286
# 2018-09-17          2.936693e+06      6879.075714
# 2018-09-14          3.527693e+06      8241.347143

# %%
df['Open'].plot(figsize=(20,8),alpha = 1)
df.rolling(window=30).mean()['Close'].plot(alpha = 1)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['Close: 30 Day Mean'] = df['Close'].rolling(window=30).mean()
df[['Close','Close: 30 Day Mean']].plot(figsize=(20,8),alpha = 1)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['Close'].expanding(min_periods=1).mean().plot(figsize=(20,8),alpha = 1)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
training_set=df['Open']
training_set=pd.DataFrame(training_set)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler(feature_range=(0,1))

# %%
training_set_df = scaler.fit_transform(training_set)

# %%
train_x = []
train_y = []

for i in range(60,2035):
    train_x.append(training_set_df[i-60:i,0])
    train_y.append(training_set_df[i,0])

# %%
train_x, train_y = np.array(train_x),np.array(train_y)

# %%
train_x = np.reshape(train_x, ( train_x.shape[0], train_x.shape[1],1))

# %%
train_x.shape
# Out:
# (1975, 60, 1)

# %%
pip install keras
# Out:
# Requirement already satisfied: keras in c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages (2.7.0)Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ip (c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages)

# %%
pip install tensorflow
# Out:
# Collecting tensorflow
#   Using cached tensorflow-2.7.0-cp39-cp39-win_amd64.whl (430.8 MB)
# Collecting tensorboard~=2.6
#   Using cached tensorboard-2.7.0-py3-none-any.whl (5.8 MB)
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (4.0.0)
# Requirement already satisfied: absl-py>=0.4.0 in c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (1.0.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (1.13.3)
# Collecting libclang>=9.0.1
#   Using cached libclang-12.0.0-py2.py3-none-win_amd64.whl (13.1 MB)
# Requirement already satisfied: keras<2.8,>=2.7.0rc0 in c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (2.7.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (1.16.0)
# Collecting flatbuffers<3.0,>=1.12
#   Using cached flatbuffers-2.0-py2.py3-none-any.whl (26 kB)
# Collecting tensorflow-estimator<2.8,~=2.7.0rc0
#   Using cached tensorflow_estimator-2.7.0-py2.py3-none-any.whl (463 kB)
# Collecting h5py>=2.9.0
#   Using cached h5py-3.6.0-cp39-cp39-win_amd64.whl (2.8 MB)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (1.21.2)
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting termcolor>=1.1.0
#   Using cached termcolor-1.1.0.tar.gz (3.9 kB)
# Collecting gast<0.5.0,>=0.2.1
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (3.19.1)
# Collecting keras-preprocessing>=1.1.1
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (0.37.0)
# Collecting tensorflow-io-gcs-filesystem>=0.21.0
#   Using cached tensorflow_io_gcs_filesystem-0.22.0-cp39-cp39-win_amd64.whl (1.5 MB)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (1.42.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow) (2.26.0)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow) (2.0.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow) (1.8.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow) (2.3.3)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow) (3.3.6)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow) (56.0.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow) (0.6.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow) (4.8.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.6->tensorflow) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2021.5.30)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2.0.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (1.26.7)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (3.1.1)
# Building wheels for collected packages: termcolor
#   Building wheel for termcolor (setup.py): started
#   Building wheel for termcolor (setup.py): finished with status 'done'Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ip (c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\aleti\appdata\local\programs\python\python39\lib\site-packages)
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4829 sha256=f0fe41b786df85620ddfaf748dc9ba1bdd78d41892f421706fcd9afe30290153
#   Stored in directory: c:\users\aleti\appdata\local\pip\cache\wheels\b6\0d\90\0d1bbd99855f99cb2f6c2e5ff96f8023fad8ec367695f7d72d
# Successfully built termcolor
# Installing collected packages: termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard, opt-einsum, libclang, keras-preprocessing, h5py, google-pasta, gast, flatbuffers, astunparse, tensorflow
# Successfully installed astunparse-1.6.3 flatbuffers-2.0 gast-0.4.0 google-pasta-0.2.0 h5py-3.6.0 keras-preprocessing-1.1.2 libclang-12.0.0 opt-einsum-3.3.0 tensorboard-2.7.0 tensorflow-2.7.0 tensorflow-estimator-2.7.0 tensorflow-io-gcs-filesystem-0.22.0 termcolor-1.1.0

# %%
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import Dense

# %%
lstm_model=Sequential()

# %%
lstm_model.add(LSTM(units=50,return_sequences=True,input_shape=(train_x.shape[1],1)))
lstm_model.add(Dropout(0.2))

# adding the second LSTM layer and add  some Dropout Regularization
lstm_model.add(LSTM(units=50,return_sequences=True))
lstm_model.add(Dropout(0.2))  
               
# adding the third LSTM layer and add  some Dropout Regularization
lstm_model.add(LSTM(units=50,return_sequences=True))
lstm_model.add(Dropout(0.2))

# %%
lstm_model.add(Dense(units = 1))
